# %% [markdown]
# ## Cleaning data having missing and duplicate values

# %% [markdown]
# ## Introduction ##

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
happiness2015 = pd.read_csv('World_Happiness_2015.csv')
happiness2016 = pd.read_csv('World_Happiness_2016.csv')
happiness2017 = pd.read_csv('World_Happiness_2017.csv')

happiness2015['YEAR'] = 2015
happiness2016['YEAR'] = 2016
happiness2017['YEAR'] = 2017

shape_2015 = happiness2015.shape
shape_2016 = happiness2016.shape
shape_2017 = happiness2017.shape

# %% [markdown]
# ## Identifying Missing Values ##

# %%
missing_2016 = happiness2016.isnull().sum()
missing_2017 = happiness2017.isnull().sum()

# %%
print(missing_2016)
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# YEAR                             0
# dtype: int64

# %%
print(missing_2017)
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# YEAR                             0
# dtype: int64

# %% [markdown]
# ## Correcting Data Cleaning Errors that Result in Missing Values ##

# %%
happiness2017.columns = happiness2017.columns.str.replace('.', ' ').str.replace('\s+', ' ').str.strip().str.upper()
happiness2015.columns = happiness2015.columns.str.replace(r'[\(\)]', '').str.strip().str.upper()
happiness2016.columns = happiness2016.columns.str.replace(r'[\(\)]', '').str.strip().str.upper()

combined = pd.concat([happiness2015, happiness2016, happiness2017], ignore_index=True, sort = True)
missing = combined.isnull().sum()
print(missing)
# Out:
# COUNTRY                          0
# DYSTOPIA RESIDUAL                0
# ECONOMY GDP PER CAPITA           0
# FAMILY                           0
# FREEDOM                          0
# GENEROSITY                       0
# HAPPINESS RANK                   0
# HAPPINESS SCORE                  0
# HEALTH LIFE EXPECTANCY           0
# LOWER CONFIDENCE INTERVAL      313
# REGION                         155
# STANDARD ERROR                 312
# TRUST GOVERNMENT CORRUPTION      0
# UPPER CONFIDENCE INTERVAL      313
# WHISKER HIGH                   315
# WHISKER LOW                    315
# YEAR                             0
# dtype: int64

# %% [markdown]
# ## Visualizing Missing Data ##

# %%
regions_2017 = combined[combined['YEAR']==2017]['REGION']
missing = regions_2017.isnull().sum()
print(missing)
# Out:
# 155

# %% [markdown]
# ## Using Data From Additional Sources to Fill in Missing Values ##

# %%
region2015 = happiness2015[['COUNTRY', 'REGION']]
region2016 = happiness2016[['COUNTRY', 'REGION']]

regions = pd.merge(left = region2015, right = region2016, how = 'left')
    
    
combined = pd.merge(left=combined, right=regions, on='COUNTRY', how='left')
combined = combined.drop('REGION_x', axis = 1)
missing = combined.isnull().sum()

# %% [markdown]
# ## Identifying Duplicates Values ##

# %%
combined['COUNTRY'] = combined['COUNTRY'].str.upper()
dups = combined.duplicated(['COUNTRY', 'YEAR'])
print(combined[dups])
# Out:
# Empty DataFrame
# Columns: [COUNTRY, DYSTOPIA RESIDUAL, ECONOMY GDP PER CAPITA, FAMILY, FREEDOM, GENEROSITY, HAPPINESS RANK, HAPPINESS SCORE, HEALTH LIFE EXPECTANCY, LOWER CONFIDENCE INTERVAL, STANDARD ERROR, TRUST GOVERNMENT CORRUPTION, UPPER CONFIDENCE INTERVAL, WHISKER HIGH, WHISKER LOW, YEAR, REGION_y]
# Index: []

# %% [markdown]
# ## Correcting Duplicates Values ##

# %%
combined['COUNTRY'] = combined['COUNTRY'].str.upper()
combined = combined.drop_duplicates(['COUNTRY', 'YEAR'])

# %% [markdown]
# ## Handle Missing Values by Dropping Columns ##

# %%
columns_to_drop = ['LOWER CONFIDENCE INTERVAL', 'STANDARD ERROR', 'UPPER CONFIDENCE INTERVAL', 'WHISKER HIGH', 'WHISKER LOW']
combined = combined.drop(columns_to_drop, axis = 1)
missing = combined.isnull().sum()

# %% [markdown]
# ## Handle Missing Values by Dropping Columns Continued ##

# %%
combined = combined.dropna(thresh=159, axis=1)
missing = combined.isnull().sum()

# %% [markdown]
# ## Handling Missing Values with Imputation ##

# %%
happiness_mean = combined['HAPPINESS SCORE'].mean()
print(happiness_mean)
combined['HAPPINESS SCORE UPDATED'] = combined['HAPPINESS SCORE'].fillna(happiness_mean)
print(combined['HAPPINESS SCORE UPDATED'].mean())
# Out:
# 5.370727659882891
# 5.370727659882891

# %% [markdown]
# ## Dropping Rows ##

# %%
combined = combined.dropna()
missing = combined.isnull().sum()

# %%
missing
# Out:
# COUNTRY                        0
# DYSTOPIA RESIDUAL              0
# ECONOMY GDP PER CAPITA         0
# FAMILY                         0
# FREEDOM                        0
# GENEROSITY                     0
# HAPPINESS RANK                 0
# HAPPINESS SCORE                0
# HEALTH LIFE EXPECTANCY         0
# TRUST GOVERNMENT CORRUPTION    0
# YEAR                           0
# REGION_y                       0
# HAPPINESS SCORE UPDATED        0
# dtype: int64

# %%
combined
# Out:
#                       COUNTRY  DYSTOPIA RESIDUAL  ECONOMY GDP PER CAPITA  \
# 0                 SWITZERLAND           2.517380                1.396510
# 1                     ICELAND           2.702010                1.302320
# 2                     DENMARK           2.492040                1.325480
# 3                      NORWAY           2.465310                1.459000
# 4                      CANADA           2.451760                1.326290
# 5                     FINLAND           2.619550                1.290250
# 6                 NETHERLANDS           2.465700                1.329440
# 7                      SWEDEN           2.371190                1.331710
# 8                 NEW ZEALAND           2.264250                1.250180
# 9                   AUSTRALIA           2.266460                1.333580
# 10                     ISRAEL           3.088540                1.228570
# 11                 COSTA RICA           3.177280                0.955780
# 12                    AUSTRIA           2.533200                1.337230
# 13                     MEXICO           3.602140                1.020540
# 14              UNITED STATES           2.510110                1.394510
# 15                     BRAZIL           3.260010                0.981240
# 16                 LUXEMBOURG           1.969610                1.563910
# 17                    IRELAND           1.975700                1.335960
# 18                    BELGIUM           2.414840                1.307820
# 19       UNITED ARAB EMIRATES           2.247430                1.427270
# 20             UNITED KINGDOM           1.969940                1.266370
# 21                       OMAN           2.474890                1.360110
# 22                  VENEZUELA           3.191310                1.044240
# 23                  SINGAPORE           1.885010                1.521860
# 24                     PANAMA           2.848480                1.063530
# 25                    GERMANY           2.115690                1.327920
# 26                      CHILE           2.675850                1.107150
# 27                      QATAR           1.556740                1.690420
# 28                     FRANCE           2.211260                1.277780
# 29                  ARGENTINA           2.836000                1.053510
# ..                        ...                ...                     ...
# 439                   GEORGIA           1.500138                0.950613
# 440          CONGO (KINSHASA)           2.224959                0.092102
# 441                      MALI           1.668191                0.476180
# 442               IVORY COAST           1.844964                0.603049
# 443                  CAMBODIA           1.042941                0.601765
# 444                     SUDAN           1.687066                0.659517
# 445                     GHANA           1.577868                0.667225
# 446                   UKRAINE           0.814382                0.894652
# 447                    UGANDA           1.526363                0.381431
# 448              BURKINA FASO           1.727213                0.350228
# 449                     NIGER           1.873983                0.161925
# 450                    MALAWI           2.081786                0.233442
# 451                      CHAD           2.071238                0.438013
# 452                  ZIMBABWE           1.597970                0.375847
# 453                   LESOTHO           1.429835                0.521021
# 454                    ANGOLA           1.614482                0.858428
# 455               AFGHANISTAN           2.150801                0.401477
# 456                  BOTSWANA           0.377914                1.122094
# 457                     BENIN           1.885631                0.431085
# 458                MADAGASCAR           1.584613                0.305809
# 459                     HAITI           1.697168                0.368610
# 460                     YEMEN           1.345601                0.591683
# 462                   LIBERIA           1.673286                0.119042
# 463                    GUINEA           1.552312                0.244550
# 464                      TOGO           1.837229                0.305445
# 465                    RWANDA           0.540061                0.368746
# 466                     SYRIA           1.061574                0.777153
# 467                  TANZANIA           0.621130                0.511136
# 468                   BURUNDI           1.683024                0.091623
# 469  CENTRAL AFRICAN REPUBLIC           2.066005                0.000000
#
#        FAMILY   FREEDOM  GENEROSITY  HAPPINESS RANK  HAPPINESS SCORE  \
# 0    1.349510  0.665570    0.296780               1            7.587
# 1    1.402230  0.628770    0.436300               2            7.561
# 2    1.360580  0.649380    0.341390               3            7.527
# 3    1.330950  0.669730    0.346990               4            7.522
# 4    1.322610  0.632970    0.458110               5            7.427
# 5    1.318260  0.641690    0.233510               6            7.406
# 6    1.280170  0.615760    0.476100               7            7.378
# 7    1.289070  0.659800    0.362620               8            7.364
# 8    1.319670  0.639380    0.475010               9            7.286
# 9    1.309230  0.651240    0.435620              10            7.284
# 10   1.223930  0.413190    0.331720              11            7.278
# 11   1.237880  0.633760    0.254970              12            7.226
# 12   1.297040  0.624330    0.330880              13            7.200
# 13   0.914510  0.481810    0.140740              14            7.187
# 14   1.247110  0.546040    0.401050              15            7.119
# 15   1.232870  0.490490    0.145740              16            6.983
# 16   1.219630  0.615830    0.280340              17            6.946
# 17   1.369480  0.617770    0.459010              18            6.940
# 18   1.285660  0.584500    0.222500              19            6.937
# 19   1.125750  0.641570    0.264280              20            6.901
# 20   1.285480  0.596250    0.519120              21            6.867
# 21   1.081820  0.632740    0.215420              22            6.853
# 22   1.255960  0.429080    0.058410              23            6.810
# 23   1.020000  0.542520    0.311050              24            6.798
# 24   1.198500  0.542100    0.244340              25            6.786
# 25   1.299370  0.614770    0.282140              26            6.750
# 26   1.124470  0.441320    0.333630              27            6.670
# 27   1.078600  0.640400    0.325730              28            6.611
# 28   1.260380  0.550110    0.123320              29            6.575
# 29   1.248230  0.449740    0.114510              30            6.574
# ..        ...       ...         ...             ...              ...
# 439  0.570615  0.309410    0.054009             125            4.286
# 440  1.229023  0.235961    0.246456             126            4.280
# 441  1.281473  0.306614    0.183354             127            4.190
# 442  0.904780  0.447706    0.201237             128            4.180
# 443  1.006238  0.633376    0.385923             129            4.168
# 444  1.214009  0.014996    0.182317             130            4.139
# 445  0.873665  0.423026    0.256924             131            4.120
# 446  1.394538  0.122975    0.270061             132            4.096
# 447  1.129828  0.443186    0.325766             133            4.081
# 448  1.043280  0.324368    0.250865             134            4.032
# 449  0.993025  0.363659    0.228674             135            4.028
# 450  0.512569  0.466915    0.287170             136            3.970
# 451  0.953856  0.162342    0.216114             137            3.936
# 452  1.083096  0.336384    0.189143             138            3.875
# 453  1.190095  0.390661    0.157497             139            3.808
# 454  1.104412  0.000000    0.097926             140            3.795
# 455  0.581543  0.106180    0.311871             141            3.794
# 456  1.221555  0.505196    0.099348             142            3.766
# 457  0.435300  0.425963    0.207948             143            3.657
# 458  0.913020  0.189197    0.208733             144            3.644
# 459  0.640450  0.030370    0.489204             145            3.603
# 460  0.935382  0.249464    0.104125             146            3.593
# 462  0.872118  0.332881    0.266550             148            3.533
# 463  0.791245  0.348588    0.264815             149            3.507
# 464  0.431883  0.380426    0.196896             150            3.495
# 465  0.945707  0.581844    0.252756             151            3.471
# 466  0.396103  0.081539    0.493664             152            3.462
# 467  1.041990  0.390018    0.354256             153            3.349
# 468  0.629794  0.059901    0.204435             154            2.905
# 469  0.000000  0.270842    0.280876             155            2.693
#
#      HEALTH LIFE EXPECTANCY  TRUST GOVERNMENT CORRUPTION  YEAR  \
# 0                  0.941430                     0.419780  2015
# 1                  0.947840                     0.141450  2015
# 2                  0.874640                     0.483570  2015
# 3                  0.885210                     0.365030  2015
# 4                  0.905630                     0.329570  2015
# 5                  0.889110                     0.413720  2015
# 6                  0.892840                     0.318140  2015
# 7                  0.910870                     0.438440  2015
# 8                  0.908370                     0.429220  2015
# 9                  0.931560                     0.356370  2015
# 10                 0.913870                     0.077850  2015
# 11                 0.860270                     0.105830  2015
# 12                 0.890420                     0.186760  2015
# 13                 0.814440                     0.213120  2015
# 14                 0.861790                     0.158900  2015
# 15                 0.697020                     0.175210  2015
# 16                 0.918940                     0.377980  2015
# 17                 0.895330                     0.287030  2015
# 18                 0.896670                     0.225400  2015
# 19                 0.809250                     0.385830  2015
# 20                 0.909430                     0.320670  2015
# 21                 0.762760                     0.325240  2015
# 22                 0.720520                     0.110690  2015
# 23                 1.025250                     0.492100  2015
# 24                 0.796610                     0.092700  2015
# 25                 0.891860                     0.218430  2015
# 26                 0.858570                     0.128690  2015
# 27                 0.797330                     0.522080  2015
# 28                 0.945790                     0.206460  2015
# 29                 0.787230                     0.084840  2015
# ..                      ...                          ...   ...
# 439                0.649547                     0.251667  2017
# 440                0.191407                     0.060241  2017
# 441                0.169366                     0.104970  2017
# 442                0.048642                     0.130062  2017
# 443                0.429783                     0.068106  2017
# 444                0.290921                     0.089848  2017
# 445                0.295638                     0.025336  2017
# 446                0.575904                     0.023029  2017
# 447                0.217633                     0.057070  2017
# 448                0.215844                     0.120328  2017
# 449                0.268505                     0.138573  2017
# 450                0.315090                     0.072712  2017
# 451                0.041135                     0.053582  2017
# 452                0.196764                     0.095375  2017
# 453                0.000000                     0.119095  2017
# 454                0.049869                     0.069720  2017
# 455                0.180747                     0.061158  2017
# 456                0.341756                     0.098583  2017
# 457                0.209930                     0.060929  2017
# 458                0.375223                     0.067232  2017
# 459                0.277321                     0.099872  2017
# 460                0.310081                     0.056767  2017
# 462                0.229918                     0.038948  2017
# 463                0.194129                     0.110938  2017
# 464                0.247106                     0.095665  2017
# 465                0.326425                     0.455220  2017
# 466                0.500533                     0.151347  2017
# 467                0.364509                     0.066035  2017
# 468                0.151611                     0.084148  2017
# 469                0.018773                     0.056565  2017
#
#                             REGION_y  HAPPINESS SCORE UPDATED
# 0                     Western Europe                    7.587
# 1                     Western Europe                    7.561
# 2                     Western Europe                    7.527
# 3                     Western Europe                    7.522
# 4                      North America                    7.427
# 5                     Western Europe                    7.406
# 6                     Western Europe                    7.378
# 7                     Western Europe                    7.364
# 8          Australia and New Zealand                    7.286
# 9          Australia and New Zealand                    7.284
# 10   Middle East and Northern Africa                    7.278
# 11       Latin America and Caribbean                    7.226
# 12                    Western Europe                    7.200
# 13       Latin America and Caribbean                    7.187
# 14                     North America                    7.119
# 15       Latin America and Caribbean                    6.983
# 16                    Western Europe                    6.946
# 17                    Western Europe                    6.940
# 18                    Western Europe                    6.937
# 19   Middle East and Northern Africa                    6.901
# 20                    Western Europe                    6.867
# 21   Middle East and Northern Africa                    6.853
# 22       Latin America and Caribbean                    6.810
# 23                 Southeastern Asia                    6.798
# 24       Latin America and Caribbean                    6.786
# 25                    Western Europe                    6.750
# 26       Latin America and Caribbean                    6.670
# 27   Middle East and Northern Africa                    6.611
# 28                    Western Europe                    6.575
# 29       Latin America and Caribbean                    6.574
# ..                               ...                      ...
# 439       Central and Eastern Europe                    4.286
# 440               Sub-Saharan Africa                    4.280
# 441               Sub-Saharan Africa                    4.190
# 442               Sub-Saharan Africa                    4.180
# 443                Southeastern Asia                    4.168
# 444               Sub-Saharan Africa                    4.139
# 445               Sub-Saharan Africa                    4.120
# 446       Central and Eastern Europe                    4.096
# 447               Sub-Saharan Africa                    4.081
# 448               Sub-Saharan Africa                    4.032
# 449               Sub-Saharan Africa                    4.028
# 450               Sub-Saharan Africa                    3.970
# 451               Sub-Saharan Africa                    3.936
# 452               Sub-Saharan Africa                    3.875
# 453               Sub-Saharan Africa                    3.808
# 454               Sub-Saharan Africa                    3.795
# 455                    Southern Asia                    3.794
# 456               Sub-Saharan Africa                    3.766
# 457               Sub-Saharan Africa                    3.657
# 458               Sub-Saharan Africa                    3.644
# 459      Latin America and Caribbean                    3.603
# 460  Middle East and Northern Africa                    3.593
# 462               Sub-Saharan Africa                    3.533
# 463               Sub-Saharan Africa                    3.507
# 464               Sub-Saharan Africa                    3.495
# 465               Sub-Saharan Africa                    3.471
# 466  Middle East and Northern Africa                    3.462
# 467               Sub-Saharan Africa                    3.349
# 468               Sub-Saharan Africa                    2.905
# 469               Sub-Saharan Africa                    2.693
#
# [458 rows x 13 columns]
